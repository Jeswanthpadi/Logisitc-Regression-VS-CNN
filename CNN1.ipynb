# %%
from sklearn.model_selection import train_test_split as holdout
import numpy as np
import pandas as pd
import warnings
import seaborn as sns
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout
from sklearn.metrics import confusion_matrix, classification_report, precision_score, accuracy_score, recall_score

# %%
warnings.filterwarnings("ignore")
plt.style.use('bmh')

# %%
df = pd.read_csv('C:/Users/svisw/Downloads/New folder/creditcard.csv')
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
classes = df['Class'].value_counts()
classes
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
fraud_share = round((classes[1]/df['Class'].count()*100),2)
fraud_share
# Out:
# 0.17

# %%
normal_share = round((classes[0]/df['Class'].count()*100),2)
normal_share
# Out:
# 99.83

# %%
# Creating fraudulent dataframe
data_fraud = df[df['Class'] == 1]
# Creating non fraudulent dataframe
data_non_fraud = df[df['Class'] == 0]

# %%
from sklearn.preprocessing import RobustScaler
rs = RobustScaler()
df['scaled_amount'] = rs.fit_transform(df['Amount'].values.reshape(-1,1))
df['scaled_time'] = rs.fit_transform(df['Time'].values.reshape(-1,1))
df.drop(['Time', 'Amount'], axis=1, inplace=True)

# %%
scaled_amount = df['scaled_amount']
scaled_time = df['scaled_time']
df.drop(['scaled_amount', 'scaled_time'], axis=1, inplace=True)
df.insert(0, 'scaled_amount', scaled_amount)
df.insert(0, 'scaled_time', scaled_time)
df.head()
# Out:
#    scaled_time  scaled_amount        V1        V2        V3        V4  \
# 0    -0.994983       1.783274 -1.359807 -0.072781  2.536347  1.378155
# 1    -0.994983      -0.269825  1.191857  0.266151  0.166480  0.448154
# 2    -0.994972       4.983721 -1.358354 -1.340163  1.773209  0.379780
# 3    -0.994972       1.418291 -0.966272 -0.185226  1.792993 -0.863291
# 4    -0.994960       0.670579 -1.158233  0.877737  1.548718  0.403034
#
#          V5        V6        V7        V8  ...       V20       V21       V22  \
# 0 -0.338321  0.462388  0.239599  0.098698  ...  0.251412 -0.018307  0.277838
# 1  0.060018 -0.082361 -0.078803  0.085102  ... -0.069083 -0.225775 -0.638672
# 2 -0.503198  1.800499  0.791461  0.247676  ...  0.524980  0.247998  0.771679
# 3 -0.010309  1.247203  0.237609  0.377436  ... -0.208038 -0.108300  0.005274
# 4 -0.407193  0.095921  0.592941 -0.270533  ...  0.408542 -0.009431  0.798278
#
#         V23       V24       V25       V26       V27       V28  Class
# ...

# %%
# Load your dataset into 'df'
x = np.array(df.iloc[:, df.columns != 'Class'])
y = np.array(df.iloc[:, df.columns == 'Class'])
x_train, x_test, y_train, y_test = holdout(x, y, test_size=0.2, random_state=0)

# %%
model = Sequential()
# Add a 1D Convolutional Layer
model.add(Conv1D(filters=32, kernel_size=5, activation='relu', input_shape=(x_train.shape[1], 1)))
# Add a MaxPooling Layer
model.add(MaxPooling1D(pool_size=2))
model.add(Flatten())
model.add(Dense(units=16, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(units=1, activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv1d_3 (Conv1D)           (None, 26, 32)            192
#
#  max_pooling1d_3 (MaxPoolin  (None, 13, 32)            0
#  g1D)
#
#  flatten_3 (Flatten)         (None, 416)               0
#
#  dense_6 (Dense)             (None, 16)                6672
#
#  dropout_3 (Dropout)         (None, 16)                0
#
#  dense_7 (Dense)             (None, 1)                 17
#
# ...
# Total params: 6881 (26.88 KB)
# Trainable params: 6881 (26.88 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.fit(x_train[:, :, np.newaxis], y_train, batch_size=15, epochs=15)  # Add an extra dimension for 1D Convolution
# Out:
# Epoch 1/15
# 15190/15190 [==============================] - 89s 6ms/step - loss: 0.0109 - accuracy: 0.9982
# Epoch 2/15
# 15190/15190 [==============================] - 84s 6ms/step - loss: 0.0066 - accuracy: 0.9983
# Epoch 3/15
# 15190/15190 [==============================] - 87s 6ms/step - loss: 0.0064 - accuracy: 0.9983
# Epoch 4/15
# 15190/15190 [==============================] - 82s 5ms/step - loss: 0.0063 - accuracy: 0.9983
# Epoch 5/15
# 15190/15190 [==============================] - 85s 6ms/step - loss: 0.0064 - accuracy: 0.9983
# Epoch 6/15
# 15190/15190 [==============================] - 98s 6ms/step - loss: 0.0064 - accuracy: 0.9985
# Epoch 7/15
# 15190/15190 [==============================] - 88s 6ms/step - loss: 0.0060 - accuracy: 0.9987
# Epoch 8/15
# 15190/15190 [==============================] - 96s 6ms/step - loss: 0.0056 - accuracy: 0.9989
# Epoch 9/15
# 15190/15190 [==============================] - 106s 7ms/step - loss: 0.0057 - accuracy: 0.9988
# Epoch 10/15
# ...

# %%
score = model.evaluate(x_test[:, :, np.newaxis], y_test)
print(score)
# Out:
# 1781/1781 [==============================] - 5s 3ms/step - loss: 0.0041 - accuracy: 0.9993
# [0.004116596654057503, 0.9993153214454651]

# %%
y_pred = (model.predict(x_test[:, :, np.newaxis]) > 0.5).astype("int32")
cnf_matrix = confusion_matrix(y_test, y_pred)
# Out:
# 1781/1781 [==============================] - 4s 2ms/step

# %%
sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="YlGnBu", fmt='g')
plt.ylabel('Actual Label')
plt.xlabel('Predicted Label')
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56861
#            1       0.90      0.69      0.78       101
#
#     accuracy                           1.00     56962
#    macro avg       0.95      0.85      0.89     56962
# weighted avg       1.00      1.00      1.00     56962
